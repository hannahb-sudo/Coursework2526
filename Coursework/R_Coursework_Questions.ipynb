# %% [markdown]
# # R Coursework part 1

# %% [markdown]
# Answer all of the questions below in the cells provided.
#
# Make sure you:
#
# - comment your code
# - run your cells to check your answers
# - save your notebook with your answers before submitting it

# %% [markdown]
# ### Question 1

# %% [markdown]
# Create a data frame with 5 rows and 2 columns. The first column should be a vector of names of your choice, the second should be a series of numeric values.

# %%
#Create vectors for dataframe
name <- c("Ashley", "Katya", "Cassie", "Karla", "Nigel")
numb <- c(23, 21, 24, 19, 17)
#Combine vectors into dataframe
df <- data.frame(name, numb)
df
# Out:
#   name   numb
# 1 Ashley 23
# 2 Katya  21
# 3 Cassie 24
# 4 Karla  19
# 5 Nigel  17

# %% [markdown]
# ### Question 2

# %% [markdown]
# The code in the cell below provides examples of each of the main data structures in R. Run the code in the cell below.

# %%
my_vector <- seq(from = 1, to = 1000, by = 1)
my_matrix <- matrix(1:100, nrow = 10, ncol = 10)
my_dataframe <- data.frame(name = rep(c("a", "b"), each = 10), value = 21:40)
my_list <- list(my_vector, my_matrix, my_dataframe)

# %% [markdown]
# Show how to access:
#
# - The 4th value of the vector
# - Column 4 and row 7 of the matrix
# - The 10th value of name in the data.frame
# - The 5th element of the 1st element of the list

# %%
#4th value of the vector
my_vector[4]

#Column 4 and row 7 of the matrix
my_matrix[7,4]

#10th value of 'name' in the data.frame
my_dataframe[10,"name"]

#5th element of the 1st element of the list
my_list[[1]][5] ##list work differently
# Out:
# [1] 4
# [1] 37
# [1] "a"
# [1] 5

# %% [markdown]
# ### Question 3

# %% [markdown]
# Show three different ways to print the numbers 200 to 300 in R. One should be a `for` loop, one should be an `sapply` function and the third can be a method of your choosing.

# %%
#Print numbers 200 to 300 with a for loop
for (i in 200:300) {
    print(i)
}

#Print numbers 200 to 300 with an sapply function
sapply(200:300, print)

#Other method 
x <- 200:300
print(x)
# Out:
# [1] 200
# [1] 201
# [1] 202
# [1] 203
# [1] 204
# [1] 205
# [1] 206
# [1] 207
# [1] 208
# [1] 209
# [1] 210
# [1] 211
# [1] 212
# [1] 213
# [1] 214
# [1] 215
# [1] 216
# [1] 217
# [1] 218
# [1] 219
# [1] 220
# [1] 221
# [1] 222
# [1] 223
# [1] 224
# [1] 225
# [1] 226
# [1] 227
# [1] 228
# [1] 229
# [1] 230
# [1] 231
# [1] 232
# [1] 233
# [1] 234
# [1] 235
# [1] 236
# [1] 237
# [1] 238
# [1] 239
# [1] 240
# [1] 241
# [1] 242
# [1] 243
# [1] 244
# [1] 245
# [1] 246
# [1] 247
# [1] 248
# [1] 249
# [1] 250
# [1] 251
# [1] 252
# [1] 253
# [1] 254
# [1] 255
# [1] 256
# [1] 257
# [1] 258
# [1] 259
# [1] 260
# [1] 261
# [1] 262
# [1] 263
# [1] 264
# [1] 265
# [1] 266
# [1] 267
# [1] 268
# [1] 269
# [1] 270
# [1] 271
# [1] 272
# [1] 273
# [1] 274
# [1] 275
# [1] 276
# [1] 277
# [1] 278
# [1] 279
# [1] 280
# [1] 281
# [1] 282
# [1] 283
# [1] 284
# [1] 285
# [1] 286
# [1] 287
# [1] 288
# [1] 289
# [1] 290
# [1] 291
# [1] 292
# [1] 293
# [1] 294
# [1] 295
# [1] 296
# [1] 297
# [1] 298
# [1] 299
# [1] 300
# [1] 200
# [1] 201
# [1] 202
# [1] 203
# [1] 204
# [1] 205
# [1] 206
# [1] 207
# [1] 208
# [1] 209
# [1] 210
# [1] 211
# [1] 212
# [1] 213
# [1] 214
# [1] 215
# [1] 216
# [1] 217
# [1] 218
# [1] 219
# [1] 220
# [1] 221
# [1] 222
# [1] 223
# [1] 224
# [1] 225
# [1] 226
# [1] 227
# [1] 228
# [1] 229
# [1] 230
# [1] 231
# [1] 232
# [1] 233
# [1] 234
# [1] 235
# [1] 236
# [1] 237
# [1] 238
# [1] 239
# [1] 240
# [1] 241
# [1] 242
# [1] 243
# [1] 244
# [1] 245
# [1] 246
# [1] 247
# [1] 248
# [1] 249
# [1] 250
# [1] 251
# [1] 252
# [1] 253
# [1] 254
# [1] 255
# [1] 256
# [1] 257
# [1] 258
# [1] 259
# [1] 260
# [1] 261
# [1] 262
# [1] 263
# [1] 264
# [1] 265
# [1] 266
# [1] 267
# [1] 268
# [1] 269
# [1] 270
# [1] 271
# [1] 272
# [1] 273
# [1] 274
# [1] 275
# [1] 276
# [1] 277
# [1] 278
# [1] 279
# [1] 280
# [1] 281
# [1] 282
# [1] 283
# [1] 284
# [1] 285
# [1] 286
# [1] 287
# [1] 288
# [1] 289
# [1] 290
# [1] 291
# [1] 292
# [1] 293
# [1] 294
# [1] 295
# [1] 296
# [1] 297
# [1] 298
# [1] 299
# [1] 300
#   [1] 200 201 202 203 204 205 206 207 208 209 210 211 212 213 214 215 216 217
#  [19] 218 219 220 221 222 223 224 225 226 227 228 229 230 231 232 233 234 235
#  [37] 236 237 238 239 240 241 242 243 244 245 246 247 248 249 250 251 252 253
#  [55] 254 255 256 257 258 259 260 261 262 263 264 265 266 267 268 269 270 271
#  [73] 272 273 274 275 276 277 278 279 280 281 282 283 284 285 286 287 288 289
#  [91] 290 291 292 293 294 295 296 297 298 299 300
#   [1] 200 201 202 203 204 205 206 207 208 209 210 211 212 213 214 215 216 217
#  [19] 218 219 220 221 222 223 224 225 226 227 228 229 230 231 232 233 234 235
#  [37] 236 237 238 239 240 241 242 243 244 245 246 247 248 249 250 251 252 253
#  [55] 254 255 256 257 258 259 260 261 262 263 264 265 266 267 268 269 270 271
#  [73] 272 273 274 275 276 277 278 279 280 281 282 283 284 285 286 287 288 289
#  [91] 290 291 292 293 294 295 296 297 298 299 300

# %% [markdown]
# ### Question 4

# %% [markdown]
# The following code creates a vector of animal names: (run this code)

# %%
animals <- c("tiger", "lion", "badger", "fox", "rabbit", "fish", "dog", "octopus")

# %% [markdown]
# Show how you would replace the fish and octopus in this dataset with two other animals without creating a new vector.

# %%
animals[6] <- "cat"
animals[8] <- "owl"
animals[]
# Out:
# [1] "tiger"  "lion"   "badger" "fox"    "rabbit" "cat"    "dog"    "owl"

# %% [markdown]
# ### Question 5

# %% [markdown]
# Using the `cars` dataset, make a `baseR` (i.e. do not use `ggplot2`) scatterplot of speed vs distance Ensure the x and y labels do not include cars$ and give your plot an appropriate title.
#
# HINT: you will have to begin by loading the cars dataset

# %%
data("cars") #Load cars dataset
#Define plot axes
speed <- cars$speed
distance <- cars$dist
#Plot speed vs. distance
plot(speed, distance, col = "blue", main = "Cars Speed vs. Distance")
# Out:
#   speed dist
# 1 4      2
# 2 4     10
# 3 7      4
# 4 7     22
# 5 8     16
# 6 9     10
# Plot with title “Cars Speed vs. Distance”

# %% [markdown]
# ### Question 6

# %% [markdown]
# Using the `starwars` dataset, identify the individuals with:
#
# - the tallest height
# - the lowest mass
#
# HINT: the starwars dataset is part of the dplyr package

# %%
library(tidyverse)
data(starwars)

starwars %>%
    select(name, height) %>%
    slice_max(height)

starwars %>%
    select(name, mass) %>%
    slice_min(mass)
# Out:
#   name        height
# 1 Yarael Poof 264
#   name         mass
# 1 Ratts Tyerel 15

# %% [markdown]
# ### Question 7

# %% [markdown]
# The `dplyr` dataset `storms` is part of the US National Oceanic and Atmospheric Administration database of Atlantic hurricanes. It contains multiple repeated measurements from hurricanes. For a given storm, there are measurements from every 6 hours across the life time of the storm.
#
# Use a tidyverse approach with `dplyr` to answer the following:
#
# - how many different storms are contained in the database?
# - which year had the most storms?
# - which storm, in which year had the highest pressure?
#
# HINT:
# unique() will help ensure you remove duplicated data from a vector e.g.
# x <- c(1, 1, 2, 2, 3, 3, 4, 4)
# unique(x)

# %%
storms_unique <- distinct(storms, name, year)
#Number of different storms contained in database
storms_unique %>%
    count(name) %>%
    tally()

#Which year had the most storms
storms_unique%>%
    slice_max(year) %>%
    tally()

#Storm and year with highest pressure
storms %>%
    select(name, year, pressure) %>%
    slice_max(pressure)
# Out:
#   n
# 1 260
#   n
# 1 16
#   name  year pressure
# 1 Danny 2003 1024
# 2 Danny 2003 1024

# %% [markdown]
# ### Question 8

# %% [markdown]
# The `ggplot2` dataset `diamonds` contains the price and information from the sale of 54,000 different diamonds. You can use ?diamonds to find out more about the dataset if you want.
#
# Using `ggplot2`:
#
# - plot the relationship between the carat (i.e. the weight of the diamond) and the price.
# - plot a histogram of prices of all the diamonds
# - plot a boxplot of the difference in price between the different cuts

# %%
#Plot of carat vs. price
ggplot(aes(x = carat, y = price), data = diamonds)+
    geom_point(color = "darkgreen")

#Histogram of prices of diamonds
ggplot(aes(x = price), data = diamonds)+
    geom_histogram(binwidth = 500, fill = "darkblue", colour = "darkblue")

#Boxplot of price vs. different cuts
ggplot(aes(x = cut, y = price), data = diamonds)+
    geom_boxplot(fill = "hotpink")
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ### Question 9

# %% [markdown]
# Identify the maximum and minimum price that the diamonds in the diamonds data set sold for. Add a new column to the diamonds data set that contains the string “Low price” if the value in the price column is less than 5000 dollars and “High price” if it is above 5000 dollars.

# %%
#Max price of diamonds
diamonds %>%
    slice_max(price)
#Min price of diamonds
diamonds %>%
    slice_min(price)
#New column for price range
diamonds %>% 
    mutate(price_range= if_else(.$price > 5000, 'High price', 'Low price')) %>%
    arrange(desc(price))
# Out:
#   carat cut     color clarity depth table price x   y    z
# 1 2.29  Premium I     VS2     60.8  60    18823 8.5 8.47 5.16
#   carat cut     color clarity depth table price x    y    z
# 1 0.23  Ideal   E     SI2     61.5  55    326   3.95 3.98 2.43
# 2 0.21  Premium E     SI1     59.8  61    326   3.89 3.84 2.31
#       carat cut       color clarity depth table price x    y    z
# 1     2.29  Premium   I     VS2     60.8  60.0  18823 8.50 8.47 5.16
# 2     2.00  Very Good G     SI1     63.5  56.0  18818 7.90 7.97 5.04
# 3     1.51  Ideal     G     IF      61.7  55.0  18806 7.37 7.41 4.56
# 4     2.07  Ideal     G     SI2     62.5  55.0  18804 8.20 8.13 5.11
# 5     2.00  Very Good H     SI1     62.8  57.0  18803 7.95 8.00 5.01
# 6     2.29  Premium   I     SI1     61.8  59.0  18797 8.52 8.45 5.24
# 7     2.04  Premium   H     SI1     58.1  60.0  18795 8.37 8.28 4.84
# 8     2.00  Premium   I     VS1     60.8  59.0  18795 8.13 8.02 4.91
# 9     1.71  Premium   F     VS2     62.3  59.0  18791 7.57 7.53 4.70
# 10    2.15  Ideal     G     SI2     62.6  54.0  18791 8.29 8.35 5.21
# 11    2.80  Good      G     SI2     63.8  58.0  18788 8.90 8.85 0.00
# 12    2.05  Ideal     G     SI1     61.9  57.0  18787 8.10 8.16 5.03
# 13    2.05  Premium   F     SI2     60.2  59.0  18784 8.28 8.33 5.00
# 14    2.03  Very Good H     SI1     63.0  60.0  18781 8.00 7.93 5.02
# 15    1.60  Ideal     F     VS1     62.0  56.0  18780 7.47 7.52 4.65
# 16    2.06  Ideal     I     VS2     62.2  55.0  18779 8.15 8.19 5.08
# 17    1.51  Very Good F     VVS1    62.6  59.0  18777 7.33 7.24 4.56
# 18    1.71  Ideal     G     VVS2    62.1  55.0  18768 7.66 7.63 4.75
# 19    2.55  Premium   I     VS1     61.8  62.0  18766 8.70 8.65 5.36
# 20    2.08  Ideal     H     SI1     58.7  60.0  18760 8.36 8.40 4.92
# 21    2.00  Very Good F     SI1     57.9  60.0  18759 8.28 8.34 4.81
# 22    2.03  Ideal     G     SI1     60.0  55.8  18757 8.17 8.30 4.95
# 23    2.61  Ideal     I     SI2     62.1  56.0  18756 8.85 8.73 5.46
# 24    2.36  Premium   H     SI2     59.4  58.0  18745 8.69 8.75 5.18
# 25    2.01  Ideal     G     SI1     62.2  56.0  18741 8.02 7.97 4.97
# 26    2.01  Very Good G     SI1     63.1  59.0  18741 8.03 7.98 5.05
# 27    2.01  Premium   G     SI1     60.3  59.0  18741 8.23 8.15 4.94
# 28    2.01  Ideal     G     SI1     62.1  57.0  18736 8.07 8.09 5.02
# 29    1.94  Premium   F     SI1     62.6  58.0  18735 7.91 7.87 4.94
# 30    2.02  Very Good E     SI1     59.8  59.0  18731 8.11 8.20 4.88
# ⋮     ⋮     ⋮         ⋮     ⋮       ⋮     ⋮     ⋮     ⋮    ⋮    ⋮
# 53911 0.25  Ideal     H     SI1     62.8  54    357   4.05 4.07 2.55
# 53912 0.23  Good      E     VS2     61.8  63    357   3.88 3.89 2.40
# 53913 0.23  Good      F     VS2     63.8  57    357   3.93 3.84 2.48
# 53914 0.24  Premium   I     VS1     62.5  57    355   3.97 3.94 2.47
# 53915 0.23  Very Good G     VVS2    60.4  58    354   3.97 4.01 2.41
# 53916 0.23  Very Good H     VS1     61.0  57    353   3.94 3.96 2.41
# 53917 0.31  Very Good J     SI1     59.4  62    353   4.39 4.43 2.62
# 53918 0.31  Very Good J     SI1     58.1  62    353   4.44 4.47 2.59
# 53919 0.23  Very Good E     VS2     63.8  55    352   3.85 3.92 2.48
# 53920 0.30  Good      J     SI1     63.4  54    351   4.23 4.29 2.70
# 53921 0.30  Good      J     SI1     63.8  56    351   4.23 4.26 2.71
# 53922 0.30  Very Good J     SI1     62.7  59    351   4.21 4.27 2.66
# 53923 0.30  Good      I     SI2     63.3  56    351   4.26 4.30 2.71
# 53924 0.30  Ideal     I     SI2     62.0  54    348   4.31 4.34 2.68
# 53925 0.20  Premium   E     SI2     60.2  62    345   3.79 3.75 2.27
# 53926 0.32  Premium   E     I1      60.9  58    345   4.38 4.42 2.68
# 53927 0.31  Ideal     J     SI2     62.2  54    344   4.35 4.37 2.71
# 53928 0.22  Premium   F     SI1     60.4  61    342   3.88 3.84 2.33
# 53929 0.23  Ideal     J     VS1     62.8  56    340   3.93 3.90 2.46
# 53930 0.30  Good      J     SI1     64.0  55    339   4.25 4.28 2.73
# 53931 0.23  Very Good H     VS1     59.4  61    338   4.00 4.05 2.39
# 53932 0.26  Very Good H     SI1     61.9  55    337   4.07 4.11 2.53
# 53933 0.22  Fair      E     VS2     65.1  61    337   3.87 3.78 2.49
# 53934 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48
# 53935 0.24  Very Good I     VVS1    62.3  57    336   3.95 3.98 2.47
# 53936 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 53937 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 53938 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 53939 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 53940 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
#       price_range
# 1     High price
# 2     High price
# 3     High price
# 4     High price
# 5     High price
# 6     High price
# 7     High price
# 8     High price
# 9     High price
# 10    High price
# 11    High price
# 12    High price
# 13    High price
# 14    High price
# 15    High price
# 16    High price
# 17    High price
# 18    High price
# 19    High price
# 20    High price
# 21    High price
# 22    High price
# 23    High price
# 24    High price
# 25    High price
# 26    High price
# 27    High price
# 28    High price
# 29    High price
# 30    High price
# ⋮     ⋮
# 53911 Low price
# 53912 Low price
# 53913 Low price
# 53914 Low price
# 53915 Low price
# 53916 Low price
# 53917 Low price
# 53918 Low price
# 53919 Low price
# 53920 Low price
# 53921 Low price
# 53922 Low price
# 53923 Low price
# 53924 Low price
# 53925 Low price
# 53926 Low price
# 53927 Low price
# 53928 Low price
# 53929 Low price
# 53930 Low price
# 53931 Low price
# 53932 Low price
# 53933 Low price
# 53934 Low price
# 53935 Low price
# 53936 Low price
# 53937 Low price
# 53938 Low price
# 53939 Low price
# 53940 Low price

# %% [markdown]
# ### Question 10

# %% [markdown]
# Sticking with the `diamonds` dataset for this question. A carat is a special unit of weight for gemstones where a single carat is 200 mg or 0.2 g. Write a function to convert the `diamonds$carat` vector into grams or milligrams. How heavy is the heaviest diamond?

# %%
carat_to_grams <- (grams = diamonds$carat * 0.2)
    max(grams)
#format nicer
# Out:
# [1] 1.002
